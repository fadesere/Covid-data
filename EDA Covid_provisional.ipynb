# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as ticker
import io
import os
import glob

import numpy as np
import scipy
import seaborn as sns

# %%
df = pd.read_csv('Provisional_COVID-19_Deaths_by_Sex_and_Age.csv')
df.sample(5)
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month     State  \
# 63555  01/18/2023  03/01/2021  03/31/2021  By Month  2021.0    3.0  Missouri
# 35217  01/18/2023  02/01/2021  02/28/2021  By Month  2021.0    2.0   Georgia
# 84039  01/18/2023  09/01/2020  09/30/2020  By Month  2020.0    9.0      Ohio
# 9633   01/18/2023  01/01/2022  12/31/2022   By Year  2022.0    NaN  New York
# 53863  01/18/2023  10/01/2020  10/31/2020  By Month  2020.0   10.0  Maryland
#
#              Sex    Age Group  COVID-19 Deaths  Total Deaths  \
# 63555  All Sexes  35-44 years              NaN         195.0
# 35217       Male  40-49 years             30.0         268.0
# 84039     Female  30-39 years              NaN         104.0
# 9633      Female  45-54 years            120.0        1767.0
# 53863  All Sexes  25-34 years              NaN         141.0
#
#        Pneumonia Deaths  Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 63555               NaN                            NaN               0.0
# 35217              21.0                           13.0               0.0
# 84039               NaN                            NaN               0.0
# 9633              139.0                           59.0               NaN
# 53863               NaN                            0.0               0.0
#
#        Pneumonia, Influenza, or COVID-19 Deaths  \
# 63555                                      12.0
# 35217                                      38.0
# 84039                                       NaN
# 9633                                      202.0
# 53863                                       NaN
#
#                                                 Footnote
# 63555  One or more data cells have counts between 1-9...
# 35217                                                NaN
# 84039  One or more data cells have counts between 1-9...
# 9633   One or more data cells have counts between 1-9...
# 53863  One or more data cells have counts between 1-9...

# %%
df.shape
# Out:
# (115668, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115668 entries, 0 to 115667
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Data As Of                                115668 non-null  object
#  1   Start Date                                115668 non-null  object
#  2   End Date                                  115668 non-null  object
#  3   Group                                     115668 non-null  object
#  4   Year                                      112914 non-null  float64
#  5   Month                                     101898 non-null  float64
#  6   State                                     115668 non-null  object
#  7   Sex                                       115668 non-null  object
#  8   Age Group                                 115668 non-null  object
#  9   COVID-19 Deaths                           83845 non-null   float64
#  10  Total Deaths                              98522 non-null   float64
#  11  Pneumonia Deaths                          79375 non-null   float64
#  12  Pneumonia and COVID-19 Deaths             85192 non-null   float64
#  13  Influenza Deaths                          93261 non-null   float64
#  14  Pneumonia, Influenza, or COVID-19 Deaths  79990 non-null   float64
#  15  Footnote                                  79898 non-null   object
# dtypes: float64(8), object(8)
# memory usage: 14.1+ MB

# %%
df.count()

# %%
df.describe()
# Out:
#                 Year          Month  COVID-19 Deaths  Total Deaths  \
# count  112914.000000  101898.000000     8.384500e+04  9.852200e+04
# mean     2021.097561       6.351351     3.517634e+02  2.812182e+03
# std         0.905405       3.519970     6.263515e+03  5.226995e+04
# min      2020.000000       1.000000     0.000000e+00  0.000000e+00
# 25%      2020.000000       3.000000     0.000000e+00  4.100000e+01
# 50%      2021.000000       6.000000     1.000000e+01  1.480000e+02
# 75%      2022.000000       9.000000     6.000000e+01  6.480000e+02
# max      2023.000000      12.000000     1.094723e+06  1.014481e+07
#
#        Pneumonia Deaths  Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# count      7.937500e+04                   85192.000000      93261.000000
# mean       3.497108e+02                     174.884355          4.937058
# std        6.016664e+03                    3162.390684        103.262381
# min        0.000000e+00                       0.000000          0.000000
# 25%        0.000000e+00                       0.000000          0.000000
# 50%        1.700000e+01                       0.000000          0.000000
# 75%        7.600000e+01                      26.000000          0.000000
# max        1.030983e+06                  550128.000000      18477.000000
#
#        Pneumonia, Influenza, or COVID-19 Deaths
# count                              7.999000e+04
# mean                               5.352093e+02
# std                                9.239907e+03
# min                                0.000000e+00
# 25%                                0.000000e+00
# 50%                                2.500000e+01
# 75%                                1.120000e+02
# max                                1.591892e+06

# %%
# Create a histogram with density curve for a single co
sns.histplot(data=df_death_sex, x="Total Deaths", kde=True)

# %%
df_death_state= pd.read_csv('Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2023.csv')
df_death_state.head(5)
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  01/15/2023  01/01/2020  01/14/2023  By Total   NaN    NaN  United States
# 1  01/15/2023  01/01/2020  01/14/2023  By Total   NaN    NaN  United States
# 2  01/15/2023  01/01/2020  01/14/2023  By Total   NaN    NaN  United States
# 3  01/15/2023  01/01/2020  01/14/2023  By Total   NaN    NaN  United States
# 4  01/15/2023  01/01/2020  01/14/2023  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID-19 Deaths  Number of Mentions Flag
# 0           1482.0              1550.0  NaN
# 1           5686.0              5902.0  NaN
# 2          14860.0             15472.0  NaN
# 3          36948.0             38395.0  NaN
# 4          81274.0             84225.0  NaN
